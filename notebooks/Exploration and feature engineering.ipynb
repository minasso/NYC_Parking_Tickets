# %%
import pandas as pd

# %%
pd.set_option('display.min_rows', 500)
pd.set_option('display.max_rows', 500)

# %%
df = pd.read_pickle('joined_data.p')

# %%
df
# Out:
#             count       temp  precip  rain
# dt
# 2016-05-04   6585  10.608333     4.7   4.7
# 2016-05-05   7578  10.437500     0.0   0.0
# 2016-05-06   5972  11.295833    10.7  10.7
# 2016-05-07   6283  11.325000     1.8   1.8
# 2016-05-09   6863  15.279167     0.0   0.0
# 2016-05-10   6990  13.595833     0.0   0.0
# 2016-05-11   7320  15.316667     0.0   0.0
# 2016-05-12   6645  17.062500     0.0   0.0
# 2016-05-13   5653  16.441667     8.7   8.7
# 2016-05-14   5979  17.575000     0.5   0.5
# 2016-05-16   6623  11.412500     0.2   0.2
# 2016-05-17   7159  14.741667     0.1   0.1
# 2016-05-18   6842  14.187500     0.0   0.0
# 2016-05-19   6918  15.358333     0.0   0.0
# 2016-05-20   6711  16.745833     0.0   0.0
# 2016-05-21   5863  15.637500     0.1   0.1
# 2016-05-23   6269  16.916667     0.6   0.6
# 2016-05-24   6689  17.600000    10.1  10.1
# 2016-05-25   6980  20.612500     0.0   0.0
# 2016-05-26   6872  23.779167     0.0   0.0
# 2016-05-27   6330  23.766667     1.8   1.8
# ...

# %%
df.loc['2018-01-03':'2018-01-10']
# Out:
#             count       temp  precip  rain amt_rain  other
# dt
# 2018-01-03   6046  -7.233333     0.0   0.0      low    0.0
# 2018-01-05   1170  -9.508333     0.1   0.0      low    0.1
# 2018-01-06   2526 -12.200000     0.0   0.0      low    0.0
# 2018-01-08   5611  -6.887500     0.6   0.2      low    0.4
# 2018-01-09   7612   0.383333     0.0   0.0      low    0.0
# 2018-01-10   7581  -1.391667     0.0   0.0      low    0.0

# %% [markdown]
# BIG PROBLEM: JAN 4 IS MISSING (YET IT IS A THURSDAY AND A NON-HOLIDAY)

# %%
df.hist(bins=10)
# Out:
# array([[<AxesSubplot:title={'center':'count'}>,
#         <AxesSubplot:title={'center':'temp'}>],
#        [<AxesSubplot:title={'center':'precip'}>,
#         <AxesSubplot:title={'center':'rain'}>]], dtype=object)

# %%
df['amt_rain']  = pd.cut(df['rain'], bins=3, labels= ['low', 'medium','high'])

# %%
df.amt_rain.value_counts()
# Out:
# low       777
# medium     30
# high        6
# Name: amt_rain, dtype: int64

# %%
f = df.groupby('amt_rain').mean()

# %%
f
# Out:
#                 count       temp     precip       rain
# amt_rain
# low       6138.893179  14.052547   2.070142   1.898842
# medium    4933.800000  15.748472  22.523333  22.523333
# high      4709.000000  15.101389  44.483333  41.716667

# %% [markdown]
# From first glance it appears that the data are relatively even in terms of count. It is a bit strange that in very high rain there are also a lot of tickets given.

# %%
rc = df.groupby('amt_rain')['count'].mean()

# %%
rc
# Out:
# amt_rain
# low       6138.893179
# medium    4933.800000
# high      4709.000000
# Name: count, dtype: float64

# %%
rc.plot(kind='barh')
# Out:
# <AxesSubplot:ylabel='amt_rain'>

# %%
import matplotlib.pyplot as plt
plt.scatter('rain','count',data=df)

# %%
df.corr()
# Out:
#            count      temp    precip      rain
# count   1.000000  0.026791 -0.322818 -0.281713
# temp    0.026791  1.000000  0.050276  0.090472
# precip -0.322818  0.050276  1.000000  0.977318
# rain   -0.281713  0.090472  0.977318  1.000000

# %% [markdown]
# About 30% of the variance in the ticket count is explained by rain/precipitation?

# %% [markdown]
# Let's add a new feature in to account for non-rain precipitation

# %%
import numpy as np

# %%
df['other'] = df['precip'] - df['rain']

# %%
df.loc[df.other>0]
# Out:
#             count      temp  precip  rain amt_rain  other
# dt
# 2016-12-05   3814  4.920833     6.1   5.9      low    0.2
# 2016-12-12   3783  3.466667    10.8  10.7      low    0.1
# 2016-12-17   2278 -2.412500    14.0   7.1      low    6.9
# 2017-01-06   6522 -1.100000     2.7   0.0      low    2.7
# 2017-01-07   1903 -4.333333     7.0   0.0      low    7.0
# 2017-01-14   5372 -0.650000     1.6   0.0      low    1.6
# 2017-01-23   5067  5.287500     8.8   8.7      low    0.1
# 2017-01-31   5951 -1.495833     1.7   0.0      low    1.7
# 2017-02-11   6598  0.683333     1.2   0.1      low    1.1
# 2017-03-10   6273  4.491667     8.3   0.1      low    8.2
# 2017-03-18   6167  0.716667     2.5   1.3      low    1.2
# 2017-12-09   2730  1.279167     7.5   0.0      low    7.5
# 2017-12-14   5058 -2.291667     1.6   0.0      low    1.6
# 2017-12-15   3482 -4.854167     1.8   0.0      low    1.8
# 2017-12-16   5254 -2.108333     0.5   0.0      low    0.5
# ...

# %% [markdown]
# Let's investigate the lower counts to see if we can find any insights

# %%
df.loc[df['count']<4000]
# Out:
#             count       temp  precip  rain amt_rain  other
# dt
# 2016-07-08   3813  26.537500     7.6   7.6      low    0.0
# 2016-07-09   3741  20.920833    14.9  14.9      low    0.0
# 2016-07-11   3875  22.558333     0.0   0.0      low    0.0
# 2016-07-16   3449  27.737500     6.0   6.0      low    0.0
# 2016-07-18   3766  27.829167     1.6   1.6      low    0.0
# 2016-07-25   3540  27.004167    15.4  15.4      low    0.0
# 2016-07-30   3484  25.154167    13.1  13.1      low    0.0
# 2016-08-01   3981  23.437500     0.9   0.9      low    0.0
# 2016-08-06   2892  25.870833     1.8   1.8      low    0.0
# 2016-08-13   3120  29.645833     2.7   2.7      low    0.0
# 2016-08-20   3806  25.920833     2.0   2.0      low    0.0
# 2016-11-29   2245  10.179167    19.4  19.4   medium    0.0
# 2016-11-30   3310  11.904167    14.4  14.4      low    0.0
# 2016-12-05   3814   4.920833     6.1   5.9      low    0.2
# 2016-12-12   3783   3.466667    10.8  10.7      low    0.1
# ...

# %%
df
# Out:
#             count       temp  precip  rain amt_rain  other
# dt
# 2016-05-04   6585  10.608333     4.7   4.7      low    0.0
# 2016-05-05   7578  10.437500     0.0   0.0      low    0.0
# 2016-05-06   5972  11.295833    10.7  10.7      low    0.0
# 2016-05-07   6283  11.325000     1.8   1.8      low    0.0
# 2016-05-09   6863  15.279167     0.0   0.0      low    0.0
# 2016-05-10   6990  13.595833     0.0   0.0      low    0.0
# 2016-05-11   7320  15.316667     0.0   0.0      low    0.0
# 2016-05-12   6645  17.062500     0.0   0.0      low    0.0
# 2016-05-13   5653  16.441667     8.7   8.7      low    0.0
# 2016-05-14   5979  17.575000     0.5   0.5      low    0.0
# 2016-05-16   6623  11.412500     0.2   0.2      low    0.0
# 2016-05-17   7159  14.741667     0.1   0.1      low    0.0
# 2016-05-18   6842  14.187500     0.0   0.0      low    0.0
# 2016-05-19   6918  15.358333     0.0   0.0      low    0.0
# 2016-05-20   6711  16.745833     0.0   0.0      low    0.0
# ...

# %% [markdown]
# 2018 count values looks much more stable over time compared to 2016, 2017.

# %%
new = df.loc['2018-01-01':]

# %%
new['temp'] = round(new['temp'] * 9/5 + 32)
# Out:
# C:\Users\rucku\AppData\Local\Temp\ipykernel_26860\3081096186.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new['temp'] = round(new['temp'] * 9/5 + 32)

# %%
new
# Out:
#             count  temp  precip  rain amt_rain  other
# dt
# 2018-01-02   5027  17.0     0.0   0.0      low    0.0
# 2018-01-03   6046  19.0     0.0   0.0      low    0.0
# 2018-01-05   1170  15.0     0.1   0.0      low    0.1
# 2018-01-06   2526  10.0     0.0   0.0      low    0.0
# 2018-01-08   5611  20.0     0.6   0.2      low    0.4
# 2018-01-09   7612  33.0     0.0   0.0      low    0.0
# 2018-01-10   7581  29.0     0.0   0.0      low    0.0
# 2018-01-11   7585  38.0     0.0   0.0      low    0.0
# 2018-01-12   4483  51.0    16.5  16.5   medium    0.0
# 2018-01-13   6738  44.0     6.8   6.8      low    0.0
# 2018-01-15   7091  20.0     0.0   0.0      low    0.0
# 2018-01-16   6763  28.0     0.0   0.0      low    0.0
# 2018-01-17   6608  33.0     5.6   3.9      low    1.7
# 2018-01-18   7035  24.0     0.0   0.0      low    0.0
# 2018-01-19   6495  28.0     0.0   0.0      low    0.0
# 2018-01-20   6846  37.0     0.0   0.0      low    0.0
# ...

# %%
new.corr()
# Out:
#            count      temp    precip      rain     other
# count   1.000000 -0.051876 -0.457898 -0.390132 -0.340811
# temp   -0.051876  1.000000  0.051571  0.106035 -0.172148
# precip -0.457898  0.051571  1.000000  0.961794  0.372070
# rain   -0.390132  0.106035  0.961794  1.000000  0.103736
# other  -0.340811 -0.172148  0.372070  0.103736  1.000000

# %% [markdown]
# The data reveals a massive correlation bw count and precip for 2018!

# %% [markdown]
# I wonder if temp might be more of a quadratic relation with either end of temp having lower tix

# %%
new.plot('temp', 'count')
# Out:
# <AxesSubplot:xlabel='temp'>

# %% [markdown]
# Need to control for precip

# %%
new.loc[new['precip']==0].plot('temp', 'count')
# Out:
# <AxesSubplot:xlabel='temp'>

# %% [markdown]
# At temps lower than 20, there seems to be some linearity to the data

# %%
new.loc[new['temp']<20]
# Out:
#             count  temp  precip  rain amt_rain  other
# dt
# 2018-01-02   5027  17.0     0.0   0.0      low    0.0
# 2018-01-03   6046  19.0     0.0   0.0      low    0.0
# 2018-01-05   1170  15.0     0.1   0.0      low    0.1
# 2018-01-06   2526  10.0     0.0   0.0      low    0.0

# %%
new
# Out:
#             count  temp  precip  rain amt_rain  other temp_scaled
# dt
# 2018-01-02   5027  17.0     0.0   0.0      low    0.0           1
# 2018-01-03   6046  19.0     0.0   0.0      low    0.0           2
# 2018-01-05   1170  15.0     0.1   0.0      low    0.1           1
# 2018-01-06   2526  10.0     0.0   0.0      low    0.0           0
# 2018-01-08   5611  20.0     0.6   0.2      low    0.4           2
# 2018-01-09   7612  33.0     0.0   0.0      low    0.0           6
# 2018-01-10   7581  29.0     0.0   0.0      low    0.0           5
# 2018-01-11   7585  38.0     0.0   0.0      low    0.0           7
# 2018-01-12   4483  51.0    16.5  16.5   medium    0.0          10
# 2018-01-13   6738  44.0     6.8   6.8      low    0.0           9
# 2018-01-15   7091  20.0     0.0   0.0      low    0.0           2
# 2018-01-16   6763  28.0     0.0   0.0      low    0.0           4
# 2018-01-17   6608  33.0     5.6   3.9      low    1.7           6
# ...

# %% [markdown]
# There was a big snowstorm on jan 5: https://www.lohud.com/story/weather/2018/01/05/bomb-cyclone-big-freeze/1004608001/

# %% [markdown]
# HUGE PROBLEM: WHY DOESN'T MY DATASET INCLUDE PRECIPITATION ON JAN 5???

# %%
new.loc[new['temp']<20].plot('temp', 'count')
# Out:
# <AxesSubplot:xlabel='temp'>

# %% [markdown]
# Let's bin the temp in approx 5 degree increments

# %%
num_bins = 20
new['temp_scaled'] = pd.cut(new['temp'],bins=num_bins,labels=range(num_bins))
# Out:
# C:\Users\rucku\AppData\Local\Temp\ipykernel_26860\517380622.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new['temp_scaled'] = pd.cut(new['temp'],bins=num_bins,labels=range(num_bins))

# %%
new.groupby('temp_scaled')['count'].mean().plot(kind='bar')
plt.title('Ticket count vs Temperature')
# Out:
# Text(0.5, 1.0, 'Ticket count vs Temperature')

# %%
new.loc[new['precip']==0].groupby('temp_scaled')['count'].mean()
# Out:
# temp_scaled
# 0     2526.000000
# 1     5027.000000
# 2     6691.666667
# 3     7097.000000
# 4     6942.833333
# 5     6692.000000
# 6     6436.900000
# 7     6746.352941
# 8     6721.090909
# 9     7272.333333
# 10    6928.875000
# 11    7242.500000
# 12    7700.500000
# 13    7404.000000
# 14    6321.500000
# 15    6606.400000
# 16    6352.857143
# 17    6349.300000
# 18    6061.125000
# 19    5759.000000
# Name: count, dtype: float64

# %%
new.loc[new['precip']==0].groupby('temp_scaled')['count'].mean().plot(kind='bar')
plt.title('Ticket count vs Temperature (adj for precip)')
# Out:
# Text(0.5, 1.0, 'Ticket count vs Temperature (adj for precip)')

# %% [markdown]
# There is a significant drop off on the lowest temps
# The effect remains when adjusted for precip

# %% [markdown]
# Perhaps we can make indicator variable for extreme low temp

# %%
min_temp = min(new['temp'])
max_temp = max(new['temp'])

# %%
(max_temp-min_temp)/30  +  min_temp
# Out:
# 12.5

# %%
import numpy as np
np.linspace(min_temp,max_temp,30)
# Out:
# array([10.        , 12.5862069 , 15.17241379, 17.75862069, 20.34482759,
#        22.93103448, 25.51724138, 28.10344828, 30.68965517, 33.27586207,
#        35.86206897, 38.44827586, 41.03448276, 43.62068966, 46.20689655,
#        48.79310345, 51.37931034, 53.96551724, 56.55172414, 59.13793103,
#        61.72413793, 64.31034483, 66.89655172, 69.48275862, 72.06896552,
#        74.65517241, 77.24137931, 79.82758621, 82.4137931 , 85.        ])

# %%
new
# Out:
#             count  temp  precip  rain amt_rain  other temp_scaled
# dt
# 2018-01-02   5027  17.0     0.0   0.0      low    0.0           1
# 2018-01-03   6046  19.0     0.0   0.0      low    0.0           2
# 2018-01-05   1170  15.0     0.1   0.0      low    0.1           1
# 2018-01-06   2526  10.0     0.0   0.0      low    0.0           0
# 2018-01-08   5611  20.0     0.6   0.2      low    0.4           2
# 2018-01-09   7612  33.0     0.0   0.0      low    0.0           6
# 2018-01-10   7581  29.0     0.0   0.0      low    0.0           5
# 2018-01-11   7585  38.0     0.0   0.0      low    0.0           7
# 2018-01-12   4483  51.0    16.5  16.5   medium    0.0          10
# 2018-01-13   6738  44.0     6.8   6.8      low    0.0           9
# 2018-01-15   7091  20.0     0.0   0.0      low    0.0           2
# 2018-01-16   6763  28.0     0.0   0.0      low    0.0           4
# 2018-01-17   6608  33.0     5.6   3.9      low    1.7           6
# ...

# %%
new['temp'].plot()
# Out:
# <AxesSubplot:xlabel='dt'>

# %%
new.loc[new['temp'].between(23,25.5)]
# Out:
#             count  temp  precip  rain amt_rain  other temp_scaled
# dt
# 2018-01-18   7035  24.0     0.0   0.0      low    0.0           3
# 2018-01-31   7483  25.0     0.0   0.0      low    0.0           3
# 2018-11-23   6773  23.0     0.0   0.0      low    0.0           3

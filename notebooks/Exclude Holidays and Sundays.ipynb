# %%
import pandas as pd

# %%
df = pd.read_csv('joined_data.csv')

# %%
df = df.dropna()

# %%
df
# Out:
#            Date  Count  precipitation (mm)  rain (mm)
# 0      1/2/2020    537                 0.0        0.0
# 1      1/3/2020   2398                 3.5        3.5
# 2      1/4/2020   4269                 4.9        4.9
# 3      1/6/2020   4163                 0.6        0.0
# 4      1/7/2020   4791                 0.1        0.1
# ..          ...    ...                 ...        ...
# 927  10/15/2022   4860                 0.0        0.0
# 928  10/16/2022      1                 0.0        0.0
# 929  10/17/2022   4689                 0.9        0.9
# 930  10/18/2022   5937                 1.5        1.5
# 931  10/19/2022   5569                 0.0        0.0
#
# [932 rows x 4 columns]

# %%
df['Date'] = pd.to_datetime(df['Date'])
# Out:
# C:\Users\rucku\AppData\Local\Temp\ipykernel_1976\2394721818.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Date'] = pd.to_datetime(df['Date'])

# %%
df[df.Count==1]
# Out:
#           Date  Count  precipitation (mm)  rain (mm)
# 48  2020-02-23      1                 0.0        0.0
# 55  2020-03-01      1                 0.0        0.0
# 69  2020-03-15      1                 0.2        0.2
# 94  2020-04-12      1                 0.0        0.0
# 172 2020-07-12      1                 0.2        0.2
# 191 2020-08-02      1                 5.2        5.2
# 198 2020-08-09      1                 0.2        0.2
# 266 2020-10-25      1                 0.0        0.0
# 294 2020-11-26      1                11.4       11.4
# 297 2020-11-29      1                 0.0        0.0
# 351 2021-01-31      1                 0.1        0.0
# 362 2021-02-14      1                 0.5        0.2
# 387 2021-03-14      1                 0.0        0.0
# 420 2021-04-18      1                 0.1        0.1
# 439 2021-05-09      1                 2.5        2.5
# 488 2021-07-04      1                 0.5        0.5
# 494 2021-07-11      1                 0.5        0.5
# ...

# %%
f = df[df.Date.dt.day_name()!='Sunday']

# %%
f.reset_index(drop=True,inplace=True)

# %%
Holidays = ['01-01', 'Memorial Day', '07-04', 'Labor Day', 'Thanksgiving Day', '12-25']

# %%
f[(f['Date'].dt.day==4) & (f['Date'].dt.month==7)]
# Out:
#           Date  Count  precipitation (mm)  rain (mm)
# 157 2020-07-04      2                 8.2        8.2
# 772 2022-07-04      1                 0.0        0.0

# %%
f[f['precipitation (mm)'] != f['rain (mm)'] ]
# Out:
#           Date  Count  precipitation (mm)  rain (mm)
# 3   2020-01-06   4163                 0.6        0.0
# 5   2020-01-08   5580                 0.8        0.5
# 14  2020-01-18   3512                 4.0        0.0
# 53  2020-03-04   5695                 2.3        2.3
# 69  2020-03-23    862                16.2       15.7
# 291 2020-12-09   2929                 0.1        0.0
# 295 2020-12-14   2340                 8.0        6.2
# 297 2020-12-16   3131                 3.1        0.0
# 298 2020-12-17      2                28.2        0.3
# 311 2021-01-04   3218                 3.8        3.5
# 325 2021-01-20   4221                 0.9        0.1
# 330 2021-01-26   3718                 5.2        1.5
# 331 2021-01-27   4404                 2.6        1.6
# 335 2021-02-03    501                 0.2        0.0
# 340 2021-02-09   2057                 2.8        0.7
# 342 2021-02-11   2066                 3.8        0.0
# 344 2021-02-13   3427                 1.3        0.0
# ...

# %%
f.dtypes
# Out:
# Date                  datetime64[ns]
# Count                          int64
# precipitation (mm)           float64
# rain (mm)                    float64
# dtype: object

# %%
f['precipitation (mm)'] = round(f['precipitation (mm)'],1)
# Out:
# C:\Users\rucku\AppData\Local\Temp\ipykernel_1976\505029827.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   f['precipitation (mm)'] = round(f['precipitation (mm)'],1)

# %%
f['rain (mm)'] = round(f['rain (mm)'],1)
# Out:
# C:\Users\rucku\AppData\Local\Temp\ipykernel_1976\310167899.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   f['rain (mm)'] = round(f['rain (mm)'],1)

# %%
f = f[f.Count>10]  # Eliminates all holidays

# %%
f[f.Count<500]
# Out:
#           Date  Count  precipitation (mm)  rain (mm)
# 73  2020-03-27    455                 0.0        0.0
# 74  2020-03-28    391                 5.3        5.3
# 75  2020-03-30    390                 1.9        1.9
# 76  2020-03-31    384                 2.2        2.2
# 77  2020-04-01    249                 0.0        0.0
# 78  2020-04-02    193                 0.0        0.0
# 79  2020-04-03    138                 5.3        5.3
# 80  2020-04-04    163                 0.1        0.1
# 81  2020-04-06    179                 0.0        0.0
# 82  2020-04-07    147                 0.0        0.0
# 83  2020-04-08    162                 6.3        6.3
# 84  2020-04-09    125                12.3       12.3
# 85  2020-04-10    122                 1.2        1.2
# 86  2020-04-11    147                 0.0        0.0
# 87  2020-04-13     68                45.4       45.4
# 88  2020-04-14    125                 0.0        0.0
# 89  2020-04-15     92                 1.8        1.8
# ...

# %%
f
# Out:
#           Date  Count  precipitation (mm)  rain (mm)
# 0   2020-01-02    537                 0.0        0.0
# 1   2020-01-03   2398                 3.5        3.5
# 2   2020-01-04   4269                 4.9        4.9
# 3   2020-01-06   4163                 0.6        0.0
# 4   2020-01-07   4791                 0.1        0.1
# ..         ...    ...                 ...        ...
# 860 2022-10-14   4398                12.6       12.6
# 861 2022-10-15   4860                 0.0        0.0
# 862 2022-10-17   4689                 0.9        0.9
# 863 2022-10-18   5937                 1.5        1.5
# 864 2022-10-19   5569                 0.0        0.0
#
# [854 rows x 4 columns]

# %%
f.columns = ['Date', 'Count', 'precip', 'rain']

# %%
f[f.rain>20]
# Out:
#           Date  Count  precip  rain
# 20  2020-01-25   3525    26.1  26.1
# 87  2020-04-13     68    45.4  45.4
# 103 2020-05-01    124    36.3  36.3
# 162 2020-07-10   1302    28.2  28.2
# 214 2020-09-10   4346    21.9  21.9
# 231 2020-09-30   5781    22.3  22.3
# 245 2020-10-16   1617    25.5  25.5
# 256 2020-10-29   1108    29.3  29.3
# 268 2020-11-12   4790    27.0  27.0
# 277 2020-11-23   4980    21.6  21.6
# 283 2020-11-30   2690    30.6  30.6
# 288 2020-12-05   2740    26.5  26.5
# 322 2021-01-16   4075    24.8  24.8
# 434 2021-05-29   3596    41.0  41.0
# 463 2021-07-02   2813    27.9  27.9
# 464 2021-07-03   2749    40.3  40.3
# 506 2021-08-23   3483    55.1  55.1
# 511 2021-08-28   2961    23.4  23.4
# 515 2021-09-02   2808    56.3  56.3
# 534 2021-09-24   1057    27.0  27.0
# 561 2021-10-26   2001    90.3  90.3
# 629 2022-01-17   3729    32.0  31.2
# 644 2022-02-04   2258    24.0  24.0
# 662 2022-02-25   3924    21.0  20.3
# 698 2022-04-08   3576    25.7  25.7
# ...

# %%
__depends__ = 'joined_data.p'
__dest__ = ''

# %%
import pandas as pd

# %%
df = pd.read_csv('temp_clean.csv')

# %%
df.loc[df['time'].between('2018-01-04 00:00:00','2018-01-06 03:00:00')]
# Out:
#                       time  temperature_2m (°C)  precipitation (mm)  rain (mm)
# 17616  2018-01-04 00:00:00                 -4.5                 0.0        0.0
# 17617  2018-01-04 01:00:00                 -4.7                 0.0        0.0
# 17618  2018-01-04 02:00:00                 -5.3                 0.0        0.0
# 17619  2018-01-04 03:00:00                 -4.9                 0.0        0.0
# 17620  2018-01-04 04:00:00                 -4.8                 0.0        0.0
# 17621  2018-01-04 05:00:00                 -4.3                 0.0        0.0
# 17622  2018-01-04 06:00:00                 -4.0                 0.1        0.0
# 17623  2018-01-04 07:00:00                 -3.6                 0.2        0.0
# 17624  2018-01-04 08:00:00                 -3.7                 0.4        0.0
# 17625  2018-01-04 09:00:00                 -3.7                 0.5        0.0
# 17626  2018-01-04 10:00:00                 -4.7                 0.7        0.0
# ...

# %% [markdown]
# Blizzard actually took place on jan 4th. May need to introduce a lag indicator which accumulates snowfall for a window of several days.
